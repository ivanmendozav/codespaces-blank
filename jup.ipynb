# %%
import numpy as np
from IPython.display import display, Markdown
import networkx as nx
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10,10,100)
y = x**2-3
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Matrices
#
# ### Creación con números aleatorios

# %%
np.random.seed(789)
A = np.random.randn(10).reshape(5,2) 
display(A)
A[[0,2],1].T
# Out:
# array([[-1.1081114 , -0.72571863],
#        [ 0.52280433,  1.2344419 ],
#        [ 0.09689585, -0.98792206],
#        [ 0.06723277, -0.59259179],
#        [-0.93177117,  1.05536277]])
# array([-0.72571863, -0.98792206])

# %%
g = nx.Graph()
g.add_edges_from([("Cuenca","Quito",{"weight":400}),
                  ("Quito","Guayaquil",{"weight":300}),
                  ("Cuenca","Guayaquil",{"weight":280})])
nx.draw(g, with_labels=True)

nx.dijkstra_path(g, "Cuenca","Quito")
# Out:
# ['Cuenca', 'Quito']

# %%
g.nodes
# Out:
# NodeView(('Cuenca', 'Quito', 'Guayaquil'))
